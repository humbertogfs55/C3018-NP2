# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 180)

def analyze_csv(path):
    try:
        df = pd.read_csv(path)
    except FileNotFoundError:
        print(f"Arquivo não encontrado: {path}\n")
        return

    print(f"Dimensões: {df.shape[0]} linhas x {df.shape[1]} colunas\n")
    print("Primeiras linhas:")
    print(df.head(), "\n")

    if "radiant_win" in df.columns:
        print("Distribuição de resultados (radiant_win):")
        print(df["radiant_win"].value_counts().to_string(), "\n")
    else:
        print("Coluna 'radiant_win' não encontrada.\n")

    print("Análise concluída.\n")


if __name__ == "__main__":
    analyze_csv("../data/processed/matches_clean.csv")
    analyze_csv("../data/processed/matches_clean_heros.csv")
# Out:
# Dimensões: 9700 linhas x 5 colunas
#
# Primeiras linhas:
#    radiant_win    radiant_team_sorted        dire_team_sorted  \
# 0         True   [2, 17, 53, 86, 121]  [14, 47, 94, 105, 110]
# 1        False  [11, 12, 27, 56, 101]   [1, 30, 90, 104, 136]
# 2         True  [6, 11, 64, 101, 104]   [21, 26, 57, 93, 107]
# 3         True  [38, 52, 72, 84, 123]   [20, 36, 40, 93, 128]
# 4        False   [23, 38, 39, 81, 96]    [11, 45, 49, 66, 71]
#
#                                       radiant_heroes  \
# 0  ['Axe', 'Storm Spirit', "Nature's Prophet", 'R...
# 1  ['Shadow Fiend', 'Phantom Lancer', 'Shadow Sha...
# 2  ['Drow Ranger', 'Shadow Fiend', 'Jakiro', 'Sky...
# 3  ['Beastmaster', 'Leshrac', 'Gyrocopter', 'Ogre...
# 4  ['Kunkka', 'Beastmaster', 'Queen of Pain', 'Ch...
#
#                                          dire_heroes
# 0  ['Pudge', 'Viper', 'Medusa', 'Techies', 'Phoen...
# 1  ['Anti-Mage', 'Witch Doctor', 'Keeper of the L...
# 2  ['Windranger', 'Lion', 'Omniknight', 'Slark', ...
# 3  ['Vengeful Spirit', 'Necrophos', 'Venomancer',...
# 4  ['Shadow Fiend', 'Pugna', 'Dragon Knight', 'Ch...
#
# Distribuição de resultados (radiant_win):
# radiant_win
# True     6256
# False    3444
#
# Análise concluída.
#
# Dimensões: 9700 linhas x 5 colunas
#
# Primeiras linhas:
#    radiant_win    radiant_team_sorted        dire_team_sorted  \
# 0         True   [2, 17, 53, 86, 121]  [14, 47, 94, 105, 110]
# 1        False  [11, 12, 27, 56, 101]   [1, 30, 90, 104, 136]
# 2         True  [6, 11, 64, 101, 104]   [21, 26, 57, 93, 107]
# 3         True  [38, 52, 72, 84, 123]   [20, 36, 40, 93, 128]
# 4        False   [23, 38, 39, 81, 96]    [11, 45, 49, 66, 71]
#
#                                       radiant_heroes  \
# 0  ['Axe', 'Storm Spirit', "Nature's Prophet", 'R...
# 1  ['Shadow Fiend', 'Phantom Lancer', 'Shadow Sha...
# 2  ['Drow Ranger', 'Shadow Fiend', 'Jakiro', 'Sky...
# 3  ['Beastmaster', 'Leshrac', 'Gyrocopter', 'Ogre...
# 4  ['Kunkka', 'Beastmaster', 'Queen of Pain', 'Ch...
#
#                                          dire_heroes
# 0  ['Pudge', 'Viper', 'Medusa', 'Techies', 'Phoen...
# 1  ['Anti-Mage', 'Witch Doctor', 'Keeper of the L...
# 2  ['Windranger', 'Lion', 'Omniknight', 'Slark', ...
# 3  ['Vengeful Spirit', 'Necrophos', 'Venomancer',...
# 4  ['Shadow Fiend', 'Pugna', 'Dragon Knight', 'Ch...
#
# Distribuição de resultados (radiant_win):
# radiant_win
# True     6256
# False    3444
#
# Análise concluída.
